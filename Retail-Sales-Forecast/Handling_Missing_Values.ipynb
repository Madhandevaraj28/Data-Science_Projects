# %% [markdown]
# Handling Missing Values

# %%
#Required libaires
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score,mean_squared_error,r2_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('/content/drive/MyDrive/Final Project/merged_datasets.csv')

# %% [markdown]
# Cleaning the null-Values using algoritham

# %%
df.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales    129909
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       271074
# MarkDown2       343582
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# Day                  0
# Month                0
# Year                 0
# Type                 0
# Size                 0
# dtype: int64

# %% [markdown]
# Weekly sales

# %%
weekly_sales = df.drop(['Temperature','Fuel_Price','MarkDown1','MarkDown2','MarkDown3','MarkDown4',
       'MarkDown5','CPI','Unemployment'],axis=1)

# %%
weekly_sales
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size
# 0         5      2  2010      1     1     1          0      24924.50  151315
# 1         5      2  2010      1     2     1          0      50605.27  151315
# 2         5      2  2010      1     3     1          0      13740.12  151315
# 3         5      2  2010      1     4     1          0      39954.04  151315
# 4         5      2  2010      1     5     1          0      32229.38  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0           NaN  118221
# 551475   26      7  2013     45    95     2          0           NaN  118221
# 551476   26      7  2013     45    96     2          0           NaN  118221
# 551477   26      7  2013     45    97     2          0           NaN  118221
# 551478   26      7  2013     45    98     2          0           NaN  118221
#
# [551479 rows x 9 columns]

# %%
weekly_sales['Weekly_Sales'].min(),weekly_sales['Weekly_Sales'].max()
# Out:
# (-4988.94, 693099.36)

# %%
#less than 1 make it as None
weekly_sales['Weekly_Sales'] = weekly_sales['Weekly_Sales'].apply(lambda x:None if x<1 else x)

# %%
weekly_sales['Weekly_Sales'].min(),weekly_sales['Weekly_Sales'].max()
# Out:
# (1.0, 693099.36)

# %%
weekly_sales.isnull().sum()
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# IsHoliday            0
# Weekly_Sales    131915
# Size                 0
# dtype: int64

# %%
weekly_null = weekly_sales.dropna()
weekly_null
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size
# 0         5      2  2010      1     1     1          0      24924.50  151315
# 1         5      2  2010      1     2     1          0      50605.27  151315
# 2         5      2  2010      1     3     1          0      13740.12  151315
# 3         5      2  2010      1     4     1          0      39954.04  151315
# 4         5      2  2010      1     5     1          0      32229.38  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 421565   26     10  2012     45    93     2          0       2487.80  118221
# 421566   26     10  2012     45    94     2          0       5203.31  118221
# 421567   26     10  2012     45    95     2          0      56017.47  118221
# 421568   26     10  2012     45    97     2          0       6817.48  118221
# 421569   26     10  2012     45    98     2          0       1076.80  118221
#
# [419564 rows x 9 columns]

# %%
x = weekly_null.drop('Weekly_Sales',axis=1)
y = weekly_null['Weekly_Sales']

# %%
x.shape,y.shape
# Out:
# ((419564, 8), (419564,))

# %% [markdown]
# Selecting algorithm

# %%
def model_regression(xtrain,xtest,ytrain,ytest,algorithm):

  for i in algorithm:
    model = i().fit(xtrain,ytrain)

    #predict for accuracy
    y_train_pred = model.predict(xtrain)

    y_test_pred = model.predict(xtest)

    #r2score prection
    r2_train = r2_score(ytrain,y_train_pred)

    r2_test = r2_score(ytest,y_test_pred)

    data = {'Algorthim':i.__name__, 'Training_r2_score':r2_train, 'Testing_r2_score':r2_test}

    print(data)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
model_regression(xtrain,xtest,ytrain,ytest,[DecisionTreeRegressor,ExtraTreeRegressor,RandomForestRegressor,GradientBoostingRegressor,XGBRegressor])
# Out:
# {'Algorthim': 'DecisionTreeRegressor', 'Training_r2_score': 1.0, 'Testing_r2_score': 0.9594563440101009}
# {'Algorthim': 'ExtraTreeRegressor', 'Training_r2_score': 0.999999999991989, 'Testing_r2_score': 0.9545894661931653}
# {'Algorthim': 'RandomForestRegressor', 'Training_r2_score': 0.9971907888309013, 'Testing_r2_score': 0.98161065999599}
# {'Algorthim': 'GradientBoostingRegressor', 'Training_r2_score': 0.7365874887937277, 'Testing_r2_score': 0.741948590832096}
# {'Algorthim': 'XGBRegressor', 'Training_r2_score': 0.9497335718695915, 'Testing_r2_score': 0.9501836429022845}

# %% [markdown]
# Here We choose Randomforest

# %%
weekly_sales_null = weekly_sales[weekly_sales.isnull().any(axis=1)]
weekly_sales_null.to_csv('weekly_sales_null.csv',index=False)
weekly_sales_nn = weekly_sales.dropna()
x = weekly_sales_nn.drop('Weekly_Sales',axis=1)
y = weekly_sales_nn['Weekly_Sales']
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
model_regression(xtrain,xtest,ytrain,ytest,[RandomForestRegressor])
# Out:
# {'Algorthim': 'RandomForestRegressor', 'Training_r2_score': 0.9970922984884604, 'Testing_r2_score': 0.9818286142322711}

# %%
weekly_sales_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size
# 0         5      2  2010      1     1     1          0      24924.50  151315
# 1         5      2  2010      1     2     1          0      50605.27  151315
# 2         5      2  2010      1     3     1          0      13740.12  151315
# 3         5      2  2010      1     4     1          0      39954.04  151315
# 4         5      2  2010      1     5     1          0      32229.38  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 421565   26     10  2012     45    93     2          0       2487.80  118221
# 421566   26     10  2012     45    94     2          0       5203.31  118221
# 421567   26     10  2012     45    95     2          0      56017.47  118221
# 421568   26     10  2012     45    97     2          0       6817.48  118221
# 421569   26     10  2012     45    98     2          0       1076.80  118221
#
# [419564 rows x 9 columns]

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/weekly_sales_null.csv')

predicted_ws = model.predict(null_df.drop('Weekly_Sales',axis=1))

null_df.drop('Weekly_Sales',axis=1,inplace=True)

null_df['Weekly_Sales'] = predicted_ws

null_df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday    Size  Weekly_Sales
# 0         5      2  2010      6    47     1          0  202505      103.7141
# 1         5      2  2010      9    49     2          0  125833       52.4812
# 2         5      2  2010     11    19     1          0  207499      354.4512
# 3         5      2  2010     15    80     2          0  123737       22.6588
# 4         5      2  2010     20    19     1          0  203742      565.6872
# ...     ...    ...   ...    ...   ...   ...        ...     ...           ...
# 131910   26      7  2013     45    94     2          0  118221     4113.1254
# 131911   26      7  2013     45    95     2          0  118221    59756.0772
# 131912   26      7  2013     45    96     2          0  118221      237.7128
# 131913   26      7  2013     45    97     2          0  118221     6775.7791
# 131914   26      7  2013     45    98     2          0  118221      711.5973
#
# [131915 rows x 9 columns]

# %%
result = pd.concat([weekly_sales_nn,null_df],axis=0,ignore_index = True)
result
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
# [551479 rows x 9 columns]

# %%
merge_columns = ['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales_x  \
# 0         5      2  2010      1     1     1          0        24924.50
# 1         5      2  2010      1     2     1          0        50605.27
# 2         5      2  2010      1     3     1          0        13740.12
# 3         5      2  2010      1     4     1          0        39954.04
# 4         5      2  2010      1     5     1          0        32229.38
# ...     ...    ...   ...    ...   ...   ...        ...             ...
# 551474   26      7  2013     45    94     2          0             NaN
# 551475   26      7  2013     45    95     2          0             NaN
# 551476   26      7  2013     45    96     2          0             NaN
# 551477   26      7  2013     45    97     2          0             NaN
# 551478   26      7  2013     45    98     2          0             NaN
#
#         Size_x  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0       151315        42.31       2.572        NaN        NaN        NaN
# 1       151315        42.31       2.572        NaN        NaN        NaN
# 2       151315        42.31       2.572        NaN        NaN        NaN
# 3       151315        42.31       2.572        NaN        NaN        NaN
# 4       151315        42.31       2.572        NaN        NaN        NaN
# ...        ...          ...         ...        ...        ...        ...
# 551474  118221        76.06       3.804     212.02     851.73       2.06
# 551475  118221        76.06       3.804     212.02     851.73       2.06
# 551476  118221        76.06       3.804     212.02     851.73       2.06
# 551477  118221        76.06       3.804     212.02     851.73       2.06
# 551478  118221        76.06       3.804     212.02     851.73       2.06
#
#         MarkDown4  MarkDown5         CPI  Unemployment  Weekly_Sales_y  Size_y
# 0             NaN        NaN  211.096358         8.106      24924.5000  151315
# 1             NaN        NaN  211.096358         8.106      50605.2700  151315
# 2             NaN        NaN  211.096358         8.106      13740.1200  151315
# 3             NaN        NaN  211.096358         8.106      39954.0400  151315
# 4             NaN        NaN  211.096358         8.106      32229.3800  151315
# ...           ...        ...         ...           ...             ...     ...
# 551474      10.88    1864.57         NaN           NaN       4113.1254  118221
# 551475      10.88    1864.57         NaN           NaN      59756.0772  118221
# 551476      10.88    1864.57         NaN           NaN        237.7128  118221
# 551477      10.88    1864.57         NaN           NaN       6775.7791  118221
# 551478      10.88    1864.57         NaN           NaN        711.5973  118221
#
# [551479 rows x 20 columns]

# %%
df['Weekly_Sales'] = md['Weekly_Sales_y']

print(df.isnull().sum())
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# IsHoliday            0
# Weekly_Sales         0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       271074
# MarkDown2       343582
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# dtype: int64

# %%
df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             42.31       2.572        NaN        NaN        NaN        NaN
# 2             42.31       2.572        NaN        NaN        NaN        NaN
# 3             42.31       2.572        NaN        NaN        NaN        NaN
# 4             42.31       2.572        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 551474        76.06       3.804     212.02     851.73       2.06      10.88
# 551475        76.06       3.804     212.02     851.73       2.06      10.88
# 551476        76.06       3.804     212.02     851.73       2.06      10.88
# 551477        76.06       3.804     212.02     851.73       2.06      10.88
# 551478        76.06       3.804     212.02     851.73       2.06      10.88
#
#         MarkDown5         CPI  Unemployment
# 0             NaN  211.096358         8.106
# 1             NaN  211.096358         8.106
# 2             NaN  211.096358         8.106
# 3             NaN  211.096358         8.106
# 4             NaN  211.096358         8.106
# ...           ...         ...           ...
# 551474    1864.57         NaN           NaN
# 551475    1864.57         NaN           NaN
# 551476    1864.57         NaN           NaN
# 551477    1864.57         NaN           NaN
# 551478    1864.57         NaN           NaN
#
# [551479 rows x 18 columns]

# %%
df['Weekly_Sales'].min(),df['Weekly_Sales'].max()
# Out:
# (1.0, 693099.36)

# %% [markdown]
# Markdown 1

# %%
mark1 = df.drop(['Weekly_Sales','Size','Temperature','Fuel_Price','MarkDown2','MarkDown3','MarkDown4','MarkDown5','CPI','Unemployment'],axis=1)
mark1
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown1
# 0         5      2  2010      1     1     1          0        NaN
# 1         5      2  2010      1     2     1          0        NaN
# 2         5      2  2010      1     3     1          0        NaN
# 3         5      2  2010      1     4     1          0        NaN
# 4         5      2  2010      1     5     1          0        NaN
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     212.02
# 551475   26      7  2013     45    95     2          0     212.02
# 551476   26      7  2013     45    96     2          0     212.02
# 551477   26      7  2013     45    97     2          0     212.02
# 551478   26      7  2013     45    98     2          0     212.02
#
# [551479 rows x 8 columns]

# %%
mark1.isnull().sum()
# Out:
# Day               0
# Month             0
# Year              0
# Store             0
# Dept              0
# Type              0
# IsHoliday         0
# MarkDown1    271074
# dtype: int64

# %%
#Null values
mark1_null = mark1[mark1.isnull().any(axis=1)]
mark1_null.to_csv('mark1_null.csv',index=False)

# %%
mark1_null.isnull().sum()
# Out:
# Day               0
# Month             0
# Year              0
# Store             0
# Dept              0
# Type              0
# IsHoliday         0
# MarkDown1    271074
# dtype: int64

# %%
mark1_null
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown1
# 0         5      2  2010      1     1     1          0        NaN
# 1         5      2  2010      1     2     1          0        NaN
# 2         5      2  2010      1     3     1          0        NaN
# 3         5      2  2010      1     4     1          0        NaN
# 4         5      2  2010      1     5     1          0        NaN
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551277   26      7  2013     42    94     3          0        NaN
# 551278   26      7  2013     42    95     3          0        NaN
# 551279   26      7  2013     42    96     3          0        NaN
# 551280   26      7  2013     42    97     3          0        NaN
# 551281   26      7  2013     42    98     3          0        NaN
#
# [271074 rows x 8 columns]

# %% [markdown]
# Non Null values

# %%
mark1_nn = mark1.dropna()
mark1_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown1
# 270138   11     11  2011      1     1     1          0   10382.90
# 270139   11     11  2011      1     2     1          0   10382.90
# 270140   11     11  2011      1     3     1          0   10382.90
# 270141   11     11  2011      1     4     1          0   10382.90
# 270142   11     11  2011      1     5     1          0   10382.90
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     212.02
# 551475   26      7  2013     45    95     2          0     212.02
# 551476   26      7  2013     45    96     2          0     212.02
# 551477   26      7  2013     45    97     2          0     212.02
# 551478   26      7  2013     45    98     2          0     212.02
#
# [280405 rows x 8 columns]

# %%
x = mark1_nn.drop('MarkDown1',axis=1)
y = mark1_nn['MarkDown1']

# %%
x.shape,y.shape
# Out:
# ((280405, 7), (280405,))

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
model_regression(xtrain,xtest,ytrain,ytest,[RandomForestRegressor])
# Out:
# {'Algorthim': 'RandomForestRegressor', 'Training_r2_score': 0.9999963226161144, 'Testing_r2_score': 0.9999785431340785}

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/mark1_null.csv')

predicted_mark1 = model.predict(null_df.drop('MarkDown1',axis=1))

result = pd.concat([mark1_nn,null_df],axis=0,ignore_index=True)

# %%
null_df.drop('MarkDown1',axis=1,inplace=True)

# %%
null_df['MarkDown1'] = predicted_mark1

# %%
mark1_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown1
# 270138   11     11  2011      1     1     1          0   10382.90
# 270139   11     11  2011      1     2     1          0   10382.90
# 270140   11     11  2011      1     3     1          0   10382.90
# 270141   11     11  2011      1     4     1          0   10382.90
# 270142   11     11  2011      1     5     1          0   10382.90
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     212.02
# 551475   26      7  2013     45    95     2          0     212.02
# 551476   26      7  2013     45    96     2          0     212.02
# 551477   26      7  2013     45    97     2          0     212.02
# 551478   26      7  2013     45    98     2          0     212.02
#
# [280405 rows x 8 columns]

# %%
null_df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown1
# 0         5      2  2010      1     1     1          0  8407.5229
# 1         5      2  2010      1     2     1          0  8407.5229
# 2         5      2  2010      1     3     1          0  8407.5229
# 3         5      2  2010      1     4     1          0  8407.5229
# 4         5      2  2010      1     5     1          0  8407.5229
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 271069   26      7  2013     42    94     3          0    48.4178
# 271070   26      7  2013     42    95     3          0    48.4178
# 271071   26      7  2013     42    96     3          0    48.4178
# 271072   26      7  2013     42    97     3          0    48.4178
# 271073   26      7  2013     42    98     3          0    48.4178
#
# [271074 rows x 8 columns]

# %%
result = pd.concat([mark1_nn,null_df],axis=0,ignore_index=True)
result
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday   MarkDown1
# 0        11     11  2011      1     1     1          0  10382.9000
# 1        11     11  2011      1     2     1          0  10382.9000
# 2        11     11  2011      1     3     1          0  10382.9000
# 3        11     11  2011      1     4     1          0  10382.9000
# 4        11     11  2011      1     5     1          0  10382.9000
# ...     ...    ...   ...    ...   ...   ...        ...         ...
# 551474   26      7  2013     42    94     3          0     48.4178
# 551475   26      7  2013     42    95     3          0     48.4178
# 551476   26      7  2013     42    96     3          0     48.4178
# 551477   26      7  2013     42    97     3          0     48.4178
# 551478   26      7  2013     42    98     3          0     48.4178
#
# [551479 rows x 8 columns]

# %%
df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             42.31       2.572        NaN        NaN        NaN        NaN
# 2             42.31       2.572        NaN        NaN        NaN        NaN
# 3             42.31       2.572        NaN        NaN        NaN        NaN
# 4             42.31       2.572        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 551474        76.06       3.804     212.02     851.73       2.06      10.88
# 551475        76.06       3.804     212.02     851.73       2.06      10.88
# 551476        76.06       3.804     212.02     851.73       2.06      10.88
# 551477        76.06       3.804     212.02     851.73       2.06      10.88
# 551478        76.06       3.804     212.02     851.73       2.06      10.88
#
#         MarkDown5         CPI  Unemployment
# 0             NaN  211.096358         8.106
# 1             NaN  211.096358         8.106
# 2             NaN  211.096358         8.106
# 3             NaN  211.096358         8.106
# 4             NaN  211.096358         8.106
# ...           ...         ...           ...
# 551474    1864.57         NaN           NaN
# 551475    1864.57         NaN           NaN
# 551476    1864.57         NaN           NaN
# 551477    1864.57         NaN           NaN
# 551478    1864.57         NaN           NaN
#
# [551479 rows x 18 columns]

# %%
merge_columns = ['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1_x  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572          NaN        NaN        NaN        NaN
# 1             42.31       2.572          NaN        NaN        NaN        NaN
# 2             42.31       2.572          NaN        NaN        NaN        NaN
# 3             42.31       2.572          NaN        NaN        NaN        NaN
# 4             42.31       2.572          NaN        NaN        NaN        NaN
# ...             ...         ...          ...        ...        ...        ...
# 551474        76.06       3.804       212.02     851.73       2.06      10.88
# 551475        76.06       3.804       212.02     851.73       2.06      10.88
# 551476        76.06       3.804       212.02     851.73       2.06      10.88
# 551477        76.06       3.804       212.02     851.73       2.06      10.88
# 551478        76.06       3.804       212.02     851.73       2.06      10.88
#
#         MarkDown5         CPI  Unemployment  MarkDown1_y
# 0             NaN  211.096358         8.106    8407.5229
# 1             NaN  211.096358         8.106    8407.5229
# 2             NaN  211.096358         8.106    8407.5229
# 3             NaN  211.096358         8.106    8407.5229
# 4             NaN  211.096358         8.106    8407.5229
# ...           ...         ...           ...          ...
# 551474    1864.57         NaN           NaN     212.0200
# 551475    1864.57         NaN           NaN     212.0200
# 551476    1864.57         NaN           NaN     212.0200
# 551477    1864.57         NaN           NaN     212.0200
# 551478    1864.57         NaN           NaN     212.0200
#
# [551479 rows x 19 columns]

# %%
df['MarkDown1'] = md['MarkDown1_y']
print(df.isnull().sum())
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# IsHoliday            0
# Weekly_Sales         0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1            0
# MarkDown2       343582
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# dtype: int64

# %%
df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572  8407.5229        NaN        NaN        NaN
# 1             42.31       2.572  8407.5229        NaN        NaN        NaN
# 2             42.31       2.572  8407.5229        NaN        NaN        NaN
# 3             42.31       2.572  8407.5229        NaN        NaN        NaN
# 4             42.31       2.572  8407.5229        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 551474        76.06       3.804   212.0200     851.73       2.06      10.88
# 551475        76.06       3.804   212.0200     851.73       2.06      10.88
# 551476        76.06       3.804   212.0200     851.73       2.06      10.88
# 551477        76.06       3.804   212.0200     851.73       2.06      10.88
# 551478        76.06       3.804   212.0200     851.73       2.06      10.88
#
#         MarkDown5         CPI  Unemployment
# 0             NaN  211.096358         8.106
# 1             NaN  211.096358         8.106
# 2             NaN  211.096358         8.106
# 3             NaN  211.096358         8.106
# 4             NaN  211.096358         8.106
# ...           ...         ...           ...
# 551474    1864.57         NaN           NaN
# 551475    1864.57         NaN           NaN
# 551476    1864.57         NaN           NaN
# 551477    1864.57         NaN           NaN
# 551478    1864.57         NaN           NaN
#
# [551479 rows x 18 columns]

# %% [markdown]
# Markdown2

# %%
mark2 = df.drop(['Weekly_Sales','Size','Temperature','Fuel_Price','MarkDown1','MarkDown3','MarkDown4','MarkDown5','CPI','Unemployment'],axis=1)
mark2
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2
# 0         5      2  2010      1     1     1          0        NaN
# 1         5      2  2010      1     2     1          0        NaN
# 2         5      2  2010      1     3     1          0        NaN
# 3         5      2  2010      1     4     1          0        NaN
# 4         5      2  2010      1     5     1          0        NaN
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     851.73
# 551475   26      7  2013     45    95     2          0     851.73
# 551476   26      7  2013     45    96     2          0     851.73
# 551477   26      7  2013     45    97     2          0     851.73
# 551478   26      7  2013     45    98     2          0     851.73
#
# [551479 rows x 8 columns]

# %%
mark2_null = mark2[mark2.isnull().any(axis=1)]

mark2_null.to_csv('mark2_null.csv',index=False)

# %%
mark2_null
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2
# 0         5      2  2010      1     1     1          0        NaN
# 1         5      2  2010      1     2     1          0        NaN
# 2         5      2  2010      1     3     1          0        NaN
# 3         5      2  2010      1     4     1          0        NaN
# 4         5      2  2010      1     5     1          0        NaN
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551400   26      7  2013     44    95     3          0        NaN
# 551401   26      7  2013     44    96     3          0        NaN
# 551402   26      7  2013     44    97     3          0        NaN
# 551403   26      7  2013     44    98     3          0        NaN
# 551404   26      7  2013     44    99     3          0        NaN
#
# [343582 rows x 8 columns]

# %%
mark2_nn = mark2.dropna()

x = mark2_nn.drop('MarkDown2',axis=1)

y = mark2_nn['MarkDown2']

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
mark2_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2
# 270138   11     11  2011      1     1     1          0    6115.67
# 270139   11     11  2011      1     2     1          0    6115.67
# 270140   11     11  2011      1     3     1          0    6115.67
# 270141   11     11  2011      1     4     1          0    6115.67
# 270142   11     11  2011      1     5     1          0    6115.67
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     851.73
# 551475   26      7  2013     45    95     2          0     851.73
# 551476   26      7  2013     45    96     2          0     851.73
# 551477   26      7  2013     45    97     2          0     851.73
# 551478   26      7  2013     45    98     2          0     851.73
#
# [207897 rows x 8 columns]

# %%
x.shape,y.shape
# Out:
# ((207897, 7), (207897,))

# %%
model_regression(xtrain,xtest,ytrain,ytest,[RandomForestRegressor])
# Out:
# {'Algorthim': 'RandomForestRegressor', 'Training_r2_score': 0.9999999646215557, 'Testing_r2_score': 0.999999832162281}

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/mark2_null.csv')

Predicted_mark2 = model.predict(null_df.drop('MarkDown2',axis=1))

null_df.drop('MarkDown2',axis=1,inplace=True)

null_df['MarkDown2'] = Predicted_mark2

# %%
null_df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2
# 0         5      2  2010      1     1     1          0  3579.2100
# 1         5      2  2010      1     2     1          0  3579.2100
# 2         5      2  2010      1     3     1          0  3579.2100
# 3         5      2  2010      1     4     1          0  3579.2100
# 4         5      2  2010      1     5     1          0  3579.2100
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 343577   26      7  2013     44    95     3          0   658.5599
# 343578   26      7  2013     44    96     3          0   658.5599
# 343579   26      7  2013     44    97     3          0   658.5599
# 343580   26      7  2013     44    98     3          0   658.5599
# 343581   26      7  2013     44    99     3          0   658.5599
#
# [343582 rows x 8 columns]

# %%
result = pd.concat([mark2_nn,null_df],axis =0,ignore_index=True)
result
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2
# 0        11     11  2011      1     1     1          0  6115.6700
# 1        11     11  2011      1     2     1          0  6115.6700
# 2        11     11  2011      1     3     1          0  6115.6700
# 3        11     11  2011      1     4     1          0  6115.6700
# 4        11     11  2011      1     5     1          0  6115.6700
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     44    95     3          0   658.5599
# 551475   26      7  2013     44    96     3          0   658.5599
# 551476   26      7  2013     44    97     3          0   658.5599
# 551477   26      7  2013     44    98     3          0   658.5599
# 551478   26      7  2013     44    99     3          0   658.5599
#
# [551479 rows x 8 columns]

# %%
merge_columns = ['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2_x  MarkDown3  MarkDown4  \
# 0             42.31       2.572  8407.5229          NaN        NaN        NaN
# 1             42.31       2.572  8407.5229          NaN        NaN        NaN
# 2             42.31       2.572  8407.5229          NaN        NaN        NaN
# 3             42.31       2.572  8407.5229          NaN        NaN        NaN
# 4             42.31       2.572  8407.5229          NaN        NaN        NaN
# ...             ...         ...        ...          ...        ...        ...
# 551474        76.06       3.804   212.0200       851.73       2.06      10.88
# 551475        76.06       3.804   212.0200       851.73       2.06      10.88
# 551476        76.06       3.804   212.0200       851.73       2.06      10.88
# 551477        76.06       3.804   212.0200       851.73       2.06      10.88
# 551478        76.06       3.804   212.0200       851.73       2.06      10.88
#
#         MarkDown5         CPI  Unemployment  MarkDown2_y
# 0             NaN  211.096358         8.106      3579.21
# 1             NaN  211.096358         8.106      3579.21
# 2             NaN  211.096358         8.106      3579.21
# 3             NaN  211.096358         8.106      3579.21
# 4             NaN  211.096358         8.106      3579.21
# ...           ...         ...           ...          ...
# 551474    1864.57         NaN           NaN       851.73
# 551475    1864.57         NaN           NaN       851.73
# 551476    1864.57         NaN           NaN       851.73
# 551477    1864.57         NaN           NaN       851.73
# 551478    1864.57         NaN           NaN       851.73
#
# [551479 rows x 19 columns]

# %%
df['MarkDown2'] = md['MarkDown2_y']
print(df.isnull().sum())
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# IsHoliday            0
# Weekly_Sales         0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1            0
# MarkDown2            0
# MarkDown3       296860
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# dtype: int64

# %% [markdown]
# MarkDown3

# %%
mark3 = df.drop(['Weekly_Sales','Size','Temperature','Fuel_Price','MarkDown1','MarkDown2','MarkDown4','MarkDown5','CPI','Unemployment'],axis=1)
mark3
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown3
# 0         5      2  2010      1     1     1          0        NaN
# 1         5      2  2010      1     2     1          0        NaN
# 2         5      2  2010      1     3     1          0        NaN
# 3         5      2  2010      1     4     1          0        NaN
# 4         5      2  2010      1     5     1          0        NaN
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0       2.06
# 551475   26      7  2013     45    95     2          0       2.06
# 551476   26      7  2013     45    96     2          0       2.06
# 551477   26      7  2013     45    97     2          0       2.06
# 551478   26      7  2013     45    98     2          0       2.06
#
# [551479 rows x 8 columns]

# %%
mark3_null = mark3[mark3.isnull().any(axis=1)]

mark3.to_csv('mark3.csv',index=False)

mark3_nn = mark3.dropna()

x = mark3_nn.drop('MarkDown3',axis=1)

y = mark3_nn['MarkDown3']

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
model_regression(xtrain,xtest,ytrain,ytest,[RandomForestRegressor])
# Out:
# {'Algorthim': 'RandomForestRegressor', 'Training_r2_score': 0.9999999998945995, 'Testing_r2_score': 0.9999999993466043}

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/mark3.csv')

predicted_mark3 = model.predict(null_df.drop('MarkDown3',axis=1))

null_df.drop('MarkDown3',axis=1,inplace=True)

null_df['MarkDown3'] = predicted_mark3

# %%
mark3_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown3
# 270138   11     11  2011      1     1     1          0     215.07
# 270139   11     11  2011      1     2     1          0     215.07
# 270140   11     11  2011      1     3     1          0     215.07
# 270141   11     11  2011      1     4     1          0     215.07
# 270142   11     11  2011      1     5     1          0     215.07
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0       2.06
# 551475   26      7  2013     45    95     2          0       2.06
# 551476   26      7  2013     45    96     2          0       2.06
# 551477   26      7  2013     45    97     2          0       2.06
# 551478   26      7  2013     45    98     2          0       2.06
#
# [254619 rows x 8 columns]

# %%
null_df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown3
# 0         5      2  2010      1     1     1          0   134.8861
# 1         5      2  2010      1     2     1          0   134.8861
# 2         5      2  2010      1     3     1          0   134.8861
# 3         5      2  2010      1     4     1          0   134.8861
# 4         5      2  2010      1     5     1          0   134.8861
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     2.0600
# 551475   26      7  2013     45    95     2          0     2.0600
# 551476   26      7  2013     45    96     2          0     2.0600
# 551477   26      7  2013     45    97     2          0     2.0600
# 551478   26      7  2013     45    98     2          0     2.0600
#
# [551479 rows x 8 columns]

# %%
result = pd.concat([mark3_nn, null_df], axis=0,ignore_index=True)

# %%
merge_columns =['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 806093   26      7  2013     45    96     2          0      237.7128  118221
# 806094   26      7  2013     45    97     2          0     6775.7791  118221
# 806095   26      7  2013     45    97     2          0     6775.7791  118221
# 806096   26      7  2013     45    98     2          0      711.5973  118221
# 806097   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3_x  MarkDown4  \
# 0             42.31       2.572  8407.5229    3579.21          NaN        NaN
# 1             42.31       2.572  8407.5229    3579.21          NaN        NaN
# 2             42.31       2.572  8407.5229    3579.21          NaN        NaN
# 3             42.31       2.572  8407.5229    3579.21          NaN        NaN
# 4             42.31       2.572  8407.5229    3579.21          NaN        NaN
# ...             ...         ...        ...        ...          ...        ...
# 806093        76.06       3.804   212.0200     851.73         2.06      10.88
# 806094        76.06       3.804   212.0200     851.73         2.06      10.88
# 806095        76.06       3.804   212.0200     851.73         2.06      10.88
# 806096        76.06       3.804   212.0200     851.73         2.06      10.88
# 806097        76.06       3.804   212.0200     851.73         2.06      10.88
#
#         MarkDown5         CPI  Unemployment  MarkDown3_y
# 0             NaN  211.096358         8.106     134.8861
# 1             NaN  211.096358         8.106     134.8861
# 2             NaN  211.096358         8.106     134.8861
# 3             NaN  211.096358         8.106     134.8861
# 4             NaN  211.096358         8.106     134.8861
# ...           ...         ...           ...          ...
# 806093    1864.57         NaN           NaN       2.0600
# 806094    1864.57         NaN           NaN       2.0600
# 806095    1864.57         NaN           NaN       2.0600
# 806096    1864.57         NaN           NaN       2.0600
# 806097    1864.57         NaN           NaN       2.0600
#
# [806098 rows x 19 columns]

# %%
df['MarkDown3'] = md['MarkDown3_y']

print(df.isnull().sum())
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# IsHoliday            0
# Weekly_Sales         0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1            0
# MarkDown2            0
# MarkDown3            0
# MarkDown4       302830
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# dtype: int64

# %% [markdown]
# MarkDown4

# %%
mark4 = df.drop(['Weekly_Sales','Size','Temperature','Fuel_Price','MarkDown1','MarkDown3','MarkDown3','MarkDown5','CPI','Unemployment'],axis=1)
mark4
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2  MarkDown4
# 0         5      2  2010      1     1     1          0    3579.21        NaN
# 1         5      2  2010      1     2     1          0    3579.21        NaN
# 2         5      2  2010      1     3     1          0    3579.21        NaN
# 3         5      2  2010      1     4     1          0    3579.21        NaN
# 4         5      2  2010      1     5     1          0    3579.21        NaN
# ...     ...    ...   ...    ...   ...   ...        ...        ...        ...
# 551474   26      7  2013     45    94     2          0     851.73      10.88
# 551475   26      7  2013     45    95     2          0     851.73      10.88
# 551476   26      7  2013     45    96     2          0     851.73      10.88
# 551477   26      7  2013     45    97     2          0     851.73      10.88
# 551478   26      7  2013     45    98     2          0     851.73      10.88
#
# [551479 rows x 9 columns]

# %%
mark4_null = mark4[mark4.isnull().any(axis=1)]

mark4_null.to_csv('mark4_null.csv',index=False)

mark4_nn = mark4.dropna()

x = mark4_nn.drop('MarkDown4',axis=1)
y = mark4_nn['MarkDown4']

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
mark4_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2  MarkDown4
# 270138   11     11  2011      1     1     1          0    6115.67    2406.62
# 270139   11     11  2011      1     2     1          0    6115.67    2406.62
# 270140   11     11  2011      1     3     1          0    6115.67    2406.62
# 270141   11     11  2011      1     4     1          0    6115.67    2406.62
# 270142   11     11  2011      1     5     1          0    6115.67    2406.62
# ...     ...    ...   ...    ...   ...   ...        ...        ...        ...
# 551474   26      7  2013     45    94     2          0     851.73      10.88
# 551475   26      7  2013     45    95     2          0     851.73      10.88
# 551476   26      7  2013     45    96     2          0     851.73      10.88
# 551477   26      7  2013     45    97     2          0     851.73      10.88
# 551478   26      7  2013     45    98     2          0     851.73      10.88
#
# [248649 rows x 9 columns]

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/mark4_null.csv')

# prediction

predicted_mark4 = model.predict(null_df.drop('MarkDown4',axis=1))

null_df.drop('MarkDown4',axis=1,inplace=True)

null_df['MarkDown4'] = predicted_mark4

null_df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2   MarkDown4
# 0         5      2  2010      1     1     1          0  3579.2100  32403.8700
# 1         5      2  2010      1     2     1          0  3579.2100  32403.8700
# 2         5      2  2010      1     3     1          0  3579.2100  32403.8700
# 3         5      2  2010      1     4     1          0  3579.2100  32403.8700
# 4         5      2  2010      1     5     1          0  3579.2100  32403.8700
# ...     ...    ...   ...    ...   ...   ...        ...        ...         ...
# 302825   26      7  2013     44    95     3          0   658.5599      6.7398
# 302826   26      7  2013     44    96     3          0   658.5599      6.7398
# 302827   26      7  2013     44    97     3          0   658.5599      6.7398
# 302828   26      7  2013     44    98     3          0   658.5599      6.7398
# 302829   26      7  2013     44    99     3          0   658.5599      6.7398
#
# [302830 rows x 9 columns]

# %%
result = pd.concat([mark4_nn, null_df], axis=0,ignore_index=True)

result
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2  MarkDown4
# 0        11     11  2011      1     1     1          0  6115.6700  2406.6200
# 1        11     11  2011      1     2     1          0  6115.6700  2406.6200
# 2        11     11  2011      1     3     1          0  6115.6700  2406.6200
# 3        11     11  2011      1     4     1          0  6115.6700  2406.6200
# 4        11     11  2011      1     5     1          0  6115.6700  2406.6200
# ...     ...    ...   ...    ...   ...   ...        ...        ...        ...
# 551474   26      7  2013     44    95     3          0   658.5599     6.7398
# 551475   26      7  2013     44    96     3          0   658.5599     6.7398
# 551476   26      7  2013     44    97     3          0   658.5599     6.7398
# 551477   26      7  2013     44    98     3          0   658.5599     6.7398
# 551478   26      7  2013     44    99     3          0   658.5599     6.7398
#
# [551479 rows x 9 columns]

# %%
merge_columns =['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2_x  MarkDown3  \
# 0             42.31       2.572  8407.5229      3579.21   134.8861
# 1             42.31       2.572  8407.5229      3579.21   134.8861
# 2             42.31       2.572  8407.5229      3579.21   134.8861
# 3             42.31       2.572  8407.5229      3579.21   134.8861
# 4             42.31       2.572  8407.5229      3579.21   134.8861
# ...             ...         ...        ...          ...        ...
# 551474        76.06       3.804   212.0200       851.73     4.7000
# 551475        76.06       3.804   212.0200       851.73     4.7000
# 551476        76.06       3.804   212.0200       851.73     4.7000
# 551477        76.06       3.804   212.0200       851.73     4.7000
# 551478        76.06       3.804   212.0200       851.73     4.7000
#
#         MarkDown4_x  MarkDown5         CPI  Unemployment  MarkDown2_y  \
# 0               NaN        NaN  211.096358         8.106      3579.21
# 1               NaN        NaN  211.096358         8.106      3579.21
# 2               NaN        NaN  211.096358         8.106      3579.21
# 3               NaN        NaN  211.096358         8.106      3579.21
# 4               NaN        NaN  211.096358         8.106      3579.21
# ...             ...        ...         ...           ...          ...
# 551474        10.88    1864.57         NaN           NaN       851.73
# 551475        10.88    1864.57         NaN           NaN       851.73
# 551476        10.88    1864.57         NaN           NaN       851.73
# 551477        10.88    1864.57         NaN           NaN       851.73
# 551478        10.88    1864.57         NaN           NaN       851.73
#
#         MarkDown4_y
# 0          32403.87
# 1          32403.87
# 2          32403.87
# 3          32403.87
# 4          32403.87
# ...             ...
# 551474        10.88
# 551475        10.88
# 551476        10.88
# 551477        10.88
# 551478        10.88
#
# [551479 rows x 20 columns]

# %%
df['MarkDown4'] = md['MarkDown4_y']

print(df.isnull().sum())
# Out:
# Day                  0
# Month                0
# Year                 0
# Store                0
# Dept                 0
# Type                 0
# IsHoliday            0
# Weekly_Sales         0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1            0
# MarkDown2            0
# MarkDown3            0
# MarkDown4            0
# MarkDown5       270138
# CPI              43303
# Unemployment     43303
# dtype: int64

# %% [markdown]
# Markdown5

# %%
mark5 = df.drop(['Weekly_Sales','Size','Temperature','Fuel_Price','MarkDown1','MarkDown2','MarkDown3','MarkDown4','CPI','Unemployment'],axis=1)
mark5
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown5
# 0         5      2  2010      1     1     1          0        NaN
# 1         5      2  2010      1     2     1          0        NaN
# 2         5      2  2010      1     3     1          0        NaN
# 3         5      2  2010      1     4     1          0        NaN
# 4         5      2  2010      1     5     1          0        NaN
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0    1864.57
# 551475   26      7  2013     45    95     2          0    1864.57
# 551476   26      7  2013     45    96     2          0    1864.57
# 551477   26      7  2013     45    97     2          0    1864.57
# 551478   26      7  2013     45    98     2          0    1864.57
#
# [551479 rows x 8 columns]

# %%
mark5_null = mark5[mark5.isnull().any(axis=1)]

mark5_null.to_csv('mark5_null.csv',index=False)

mark5_nn = mark5.dropna()

x = mark5_nn.drop('MarkDown5',axis=1)
y = mark5_nn['MarkDown5']

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
mark5_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown5
# 270138   11     11  2011      1     1     1          0    6551.42
# 270139   11     11  2011      1     2     1          0    6551.42
# 270140   11     11  2011      1     3     1          0    6551.42
# 270141   11     11  2011      1     4     1          0    6551.42
# 270142   11     11  2011      1     5     1          0    6551.42
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0    1864.57
# 551475   26      7  2013     45    95     2          0    1864.57
# 551476   26      7  2013     45    96     2          0    1864.57
# 551477   26      7  2013     45    97     2          0    1864.57
# 551478   26      7  2013     45    98     2          0    1864.57
#
# [281341 rows x 8 columns]

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/mark5_null.csv')

# prediction

predicted_mark5 = model.predict(null_df.drop('MarkDown5',axis=1))

null_df.drop('MarkDown5',axis=1,inplace=True)

null_df['MarkDown5'] = predicted_mark5

result = pd.concat([mark5_nn, null_df], axis=0,ignore_index=True)

result
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown5
# 0        11     11  2011      1     1     1          0  6551.4200
# 1        11     11  2011      1     2     1          0  6551.4200
# 2        11     11  2011      1     3     1          0  6551.4200
# 3        11     11  2011      1     4     1          0  6551.4200
# 4        11     11  2011      1     5     1          0  6551.4200
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474    4     11  2011     45    93     2          0  5071.3041
# 551475    4     11  2011     45    94     2          0  5071.3041
# 551476    4     11  2011     45    95     2          0  5071.3041
# 551477    4     11  2011     45    97     2          0  5071.3041
# 551478    4     11  2011     45    98     2          0  5071.3041
#
# [551479 rows x 8 columns]

# %%
null_df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown5
# 0         5      2  2010      1     1     1          0  6588.9480
# 1         5      2  2010      1     2     1          0  6588.9480
# 2         5      2  2010      1     3     1          0  6588.9480
# 3         5      2  2010      1     4     1          0  6588.9480
# 4         5      2  2010      1     5     1          0  6588.9480
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 270133    4     11  2011     45    93     2          0  5071.3041
# 270134    4     11  2011     45    94     2          0  5071.3041
# 270135    4     11  2011     45    95     2          0  5071.3041
# 270136    4     11  2011     45    97     2          0  5071.3041
# 270137    4     11  2011     45    98     2          0  5071.3041
#
# [270138 rows x 8 columns]

# %%
merge_columns =['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 1             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 2             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 3             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 4             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# ...             ...         ...        ...        ...        ...        ...
# 551474        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551475        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551476        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551477        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551478        76.06       3.804   212.0200     851.73     4.7000      10.88
#
#         MarkDown5_x         CPI  Unemployment  MarkDown5_y
# 0               NaN  211.096358         8.106     6588.948
# 1               NaN  211.096358         8.106     6588.948
# 2               NaN  211.096358         8.106     6588.948
# 3               NaN  211.096358         8.106     6588.948
# 4               NaN  211.096358         8.106     6588.948
# ...             ...         ...           ...          ...
# 551474      1864.57         NaN           NaN     1864.570
# 551475      1864.57         NaN           NaN     1864.570
# 551476      1864.57         NaN           NaN     1864.570
# 551477      1864.57         NaN           NaN     1864.570
# 551478      1864.57         NaN           NaN     1864.570
#
# [551479 rows x 19 columns]

# %%
df['MarkDown5'] = md['MarkDown5_y']

print(df.isnull().sum())
# Out:
# Day                 0
# Month               0
# Year                0
# Store               0
# Dept                0
# Type                0
# IsHoliday           0
# Weekly_Sales        0
# Size                0
# Temperature         0
# Fuel_Price          0
# MarkDown1           0
# MarkDown2           0
# MarkDown3           0
# MarkDown4           0
# MarkDown5           0
# CPI             43303
# Unemployment    43303
# dtype: int64

# %% [markdown]
# CPI

# %%
cpi = df.drop(['Weekly_Sales','Size','Temperature','Fuel_Price','MarkDown1','MarkDown3','MarkDown4','MarkDown5','Unemployment'],axis=1)
cpi
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2         CPI
# 0         5      2  2010      1     1     1          0    3579.21  211.096358
# 1         5      2  2010      1     2     1          0    3579.21  211.096358
# 2         5      2  2010      1     3     1          0    3579.21  211.096358
# 3         5      2  2010      1     4     1          0    3579.21  211.096358
# 4         5      2  2010      1     5     1          0    3579.21  211.096358
# ...     ...    ...   ...    ...   ...   ...        ...        ...         ...
# 551474   26      7  2013     45    94     2          0     851.73         NaN
# 551475   26      7  2013     45    95     2          0     851.73         NaN
# 551476   26      7  2013     45    96     2          0     851.73         NaN
# 551477   26      7  2013     45    97     2          0     851.73         NaN
# 551478   26      7  2013     45    98     2          0     851.73         NaN
#
# [551479 rows x 9 columns]

# %%
cpi_null = cpi[cpi.isnull().any(axis=1)]

cpi_null.to_csv('cpi_null.csv',index=False)

cpi_nn = cpi.dropna()

x = cpi_nn.drop('CPI',axis=1)
y = cpi_nn['CPI']

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
cpi_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2         CPI
# 0         5      2  2010      1     1     1          0  3579.2100  211.096358
# 1         5      2  2010      1     2     1          0  3579.2100  211.096358
# 2         5      2  2010      1     3     1          0  3579.2100  211.096358
# 3         5      2  2010      1     4     1          0  3579.2100  211.096358
# 4         5      2  2010      1     5     1          0  3579.2100  211.096358
# ...     ...    ...   ...    ...   ...   ...        ...        ...         ...
# 508171   26      4  2013     45    94     2          0    38.5328  193.589304
# 508172   26      4  2013     45    95     2          0    38.5328  193.589304
# 508173   26      4  2013     45    96     2          0    38.5328  193.589304
# 508174   26      4  2013     45    97     2          0    38.5328  193.589304
# 508175   26      4  2013     45    98     2          0    38.5328  193.589304
#
# [508176 rows x 9 columns]

# %%
model_regression(xtrain,xtest,ytrain,ytest,[RandomForestRegressor])
# Out:
# {'Algorthim': 'RandomForestRegressor', 'Training_r2_score': 0.9999999999931934, 'Testing_r2_score': 0.999999999652355}

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/cpi_null.csv')

# prediction

predicted_cpi = model.predict(null_df.drop('CPI',axis=1))

null_df.drop('CPI',axis=1,inplace=True)

null_df['CPI'] = predicted_cpi

# %%
null_df
# Out:
#        Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2         CPI
# 0        3      5  2013      1     1     1          0       2.00  225.126677
# 1        3      5  2013      1     2     1          0       2.00  225.126677
# 2        3      5  2013      1     3     1          0       2.00  225.126677
# 3        3      5  2013      1     4     1          0       2.00  225.126677
# 4        3      5  2013      1     5     1          0       2.00  225.126677
# ...    ...    ...   ...    ...   ...   ...        ...        ...         ...
# 43298   26      7  2013     45    94     2          0     851.73  193.589304
# 43299   26      7  2013     45    95     2          0     851.73  193.589304
# 43300   26      7  2013     45    96     2          0     851.73  193.589304
# 43301   26      7  2013     45    97     2          0     851.73  193.589304
# 43302   26      7  2013     45    98     2          0     851.73  193.589304
#
# [43303 rows x 9 columns]

# %%
result = pd.concat([cpi_nn, null_df], axis=0,ignore_index=True)

result
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2         CPI
# 0         5      2  2010      1     1     1          0    3579.21  211.096358
# 1         5      2  2010      1     2     1          0    3579.21  211.096358
# 2         5      2  2010      1     3     1          0    3579.21  211.096358
# 3         5      2  2010      1     4     1          0    3579.21  211.096358
# 4         5      2  2010      1     5     1          0    3579.21  211.096358
# ...     ...    ...   ...    ...   ...   ...        ...        ...         ...
# 551474   26      7  2013     45    94     2          0     851.73  193.589304
# 551475   26      7  2013     45    95     2          0     851.73  193.589304
# 551476   26      7  2013     45    96     2          0     851.73  193.589304
# 551477   26      7  2013     45    97     2          0     851.73  193.589304
# 551478   26      7  2013     45    98     2          0     851.73  193.589304
#
# [551479 rows x 9 columns]

# %%
merge_columns =['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2_x  MarkDown3  MarkDown4  \
# 0             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 1             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 2             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 3             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 4             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# ...             ...         ...        ...          ...        ...        ...
# 551474        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551475        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551476        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551477        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551478        76.06       3.804   212.0200       851.73     4.7000      10.88
#
#         MarkDown5       CPI_x  Unemployment  MarkDown2_y       CPI_y
# 0        6588.948  211.096358         8.106      3579.21  211.096358
# 1        6588.948  211.096358         8.106      3579.21  211.096358
# 2        6588.948  211.096358         8.106      3579.21  211.096358
# 3        6588.948  211.096358         8.106      3579.21  211.096358
# 4        6588.948  211.096358         8.106      3579.21  211.096358
# ...           ...         ...           ...          ...         ...
# 551474   1864.570         NaN           NaN       851.73  193.589304
# 551475   1864.570         NaN           NaN       851.73  193.589304
# 551476   1864.570         NaN           NaN       851.73  193.589304
# 551477   1864.570         NaN           NaN       851.73  193.589304
# 551478   1864.570         NaN           NaN       851.73  193.589304
#
# [551479 rows x 20 columns]

# %%
df['CPI'] = md['CPI_y']

print(df.isnull().sum())
# Out:
# Day                 0
# Month               0
# Year                0
# Store               0
# Dept                0
# Type                0
# IsHoliday           0
# Weekly_Sales        0
# Size                0
# Temperature         0
# Fuel_Price          0
# MarkDown1           0
# MarkDown2           0
# MarkDown3           0
# MarkDown4           0
# MarkDown5           0
# CPI                 0
# Unemployment    43303
# dtype: int64

# %% [markdown]
# Unemployment

# %%
unemployment = df.drop(['Weekly_Sales','Size','Temperature','Fuel_Price','MarkDown1','MarkDown3','MarkDown4','MarkDown5','CPI',],axis=1)
unemployment
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2  \
# 0         5      2  2010      1     1     1          0    3579.21
# 1         5      2  2010      1     2     1          0    3579.21
# 2         5      2  2010      1     3     1          0    3579.21
# 3         5      2  2010      1     4     1          0    3579.21
# 4         5      2  2010      1     5     1          0    3579.21
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     851.73
# 551475   26      7  2013     45    95     2          0     851.73
# 551476   26      7  2013     45    96     2          0     851.73
# 551477   26      7  2013     45    97     2          0     851.73
# 551478   26      7  2013     45    98     2          0     851.73
#
#         Unemployment
# 0              8.106
# 1              8.106
# 2              8.106
# 3              8.106
# 4              8.106
# ...              ...
# 551474           NaN
# 551475           NaN
# 551476           NaN
# 551477           NaN
# 551478           NaN
#
# [551479 rows x 9 columns]

# %%
unemployment_null = unemployment[unemployment.isnull().any(axis=1)]

unemployment_null.to_csv('unemployment_null.csv',index=False)

unemployment_nn = unemployment.dropna()

x = unemployment_nn.drop('Unemployment',axis=1)

y = unemployment_nn['Unemployment']

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

unemployment_nn
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2  \
# 0         5      2  2010      1     1     1          0  3579.2100
# 1         5      2  2010      1     2     1          0  3579.2100
# 2         5      2  2010      1     3     1          0  3579.2100
# 3         5      2  2010      1     4     1          0  3579.2100
# 4         5      2  2010      1     5     1          0  3579.2100
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 508171   26      4  2013     45    94     2          0    38.5328
# 508172   26      4  2013     45    95     2          0    38.5328
# 508173   26      4  2013     45    96     2          0    38.5328
# 508174   26      4  2013     45    97     2          0    38.5328
# 508175   26      4  2013     45    98     2          0    38.5328
#
#         Unemployment
# 0              8.106
# 1              8.106
# 2              8.106
# 3              8.106
# 4              8.106
# ...              ...
# 508171         8.335
# 508172         8.335
# 508173         8.335
# 508174         8.335
# 508175         8.335
#
# [508176 rows x 9 columns]

# %%
model_regression(xtrain,xtest,ytrain,ytest,[RandomForestRegressor])
# Out:
# {'Algorthim': 'RandomForestRegressor', 'Training_r2_score': 1.0, 'Testing_r2_score': 1.0}

# %%
model = RandomForestRegressor().fit(xtrain,ytrain)

null_df = pd.read_csv('/content/unemployment_null.csv')

# %%
predicted_Unemployment = model.predict(null_df.drop('Unemployment',axis=1))

null_df.drop('Unemployment',axis=1,inplace=True)

null_df['Unemployment'] = predicted_Unemployment

# %%
null_df
# Out:
#        Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2  Unemployment
# 0        3      5  2013      1     1     1          0       2.00         6.314
# 1        3      5  2013      1     2     1          0       2.00         6.314
# 2        3      5  2013      1     3     1          0       2.00         6.314
# 3        3      5  2013      1     4     1          0       2.00         6.314
# 4        3      5  2013      1     5     1          0       2.00         6.314
# ...    ...    ...   ...    ...   ...   ...        ...        ...           ...
# 43298   26      7  2013     45    94     2          0     851.73         8.684
# 43299   26      7  2013     45    95     2          0     851.73         8.684
# 43300   26      7  2013     45    96     2          0     851.73         8.684
# 43301   26      7  2013     45    97     2          0     851.73         8.684
# 43302   26      7  2013     45    98     2          0     851.73         8.684
#
# [43303 rows x 9 columns]

# %%
result = pd.concat([unemployment_nn, null_df], axis=0,ignore_index=True)
result
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  MarkDown2  \
# 0         5      2  2010      1     1     1          0    3579.21
# 1         5      2  2010      1     2     1          0    3579.21
# 2         5      2  2010      1     3     1          0    3579.21
# 3         5      2  2010      1     4     1          0    3579.21
# 4         5      2  2010      1     5     1          0    3579.21
# ...     ...    ...   ...    ...   ...   ...        ...        ...
# 551474   26      7  2013     45    94     2          0     851.73
# 551475   26      7  2013     45    95     2          0     851.73
# 551476   26      7  2013     45    96     2          0     851.73
# 551477   26      7  2013     45    97     2          0     851.73
# 551478   26      7  2013     45    98     2          0     851.73
#
#         Unemployment
# 0              8.106
# 1              8.106
# 2              8.106
# 3              8.106
# 4              8.106
# ...              ...
# 551474         8.684
# 551475         8.684
# 551476         8.684
# 551477         8.684
# 551478         8.684
#
# [551479 rows x 9 columns]

# %%
merge_columns =['Day','Month','Year','Store','Dept','Type','IsHoliday']

md = df.merge(result, on=merge_columns, how='left')

md
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2_x  MarkDown3  MarkDown4  \
# 0             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 1             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 2             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 3             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# 4             42.31       2.572  8407.5229      3579.21   134.8861   32403.87
# ...             ...         ...        ...          ...        ...        ...
# 551474        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551475        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551476        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551477        76.06       3.804   212.0200       851.73     4.7000      10.88
# 551478        76.06       3.804   212.0200       851.73     4.7000      10.88
#
#         MarkDown5         CPI  Unemployment_x  MarkDown2_y  Unemployment_y
# 0        6588.948  211.096358           8.106      3579.21           8.106
# 1        6588.948  211.096358           8.106      3579.21           8.106
# 2        6588.948  211.096358           8.106      3579.21           8.106
# 3        6588.948  211.096358           8.106      3579.21           8.106
# 4        6588.948  211.096358           8.106      3579.21           8.106
# ...           ...         ...             ...          ...             ...
# 551474   1864.570  193.589304             NaN       851.73           8.684
# 551475   1864.570  193.589304             NaN       851.73           8.684
# 551476   1864.570  193.589304             NaN       851.73           8.684
# 551477   1864.570  193.589304             NaN       851.73           8.684
# 551478   1864.570  193.589304             NaN       851.73           8.684
#
# [551479 rows x 20 columns]

# %%
df['Unemployment'] = md['Unemployment_y']

print(df.isnull().sum())
# Out:
# Day             0
# Month           0
# Year            0
# Store           0
# Dept            0
# Type            0
# IsHoliday       0
# Weekly_Sales    0
# Size            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# Correlation Check

# %%
plt.figure(figsize=(15,10))
sn.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Summary stats

# %%
df.describe().T
# Out:
#                  count           mean           std        min           25%  \
# Day           551479.0      15.653488      8.776044      1.000      8.000000
# Month         551479.0       6.277180      3.340134      1.000      3.000000
# Year          551479.0    2011.392758      1.054086   2010.000   2010.000000
# Store         551479.0      22.270485     12.796872      1.000     11.000000
# Dept          551479.0      44.603013     30.416079      1.000     19.000000
# Type          551479.0       1.594791      0.669624      1.000      1.000000
# IsHoliday     551479.0       0.071905      0.258330      0.000      0.000000
# Weekly_Sales  551479.0   15691.589196  22750.405248      1.000   1810.760000
# Size          551479.0  136073.691863  61207.331445  34875.000  93638.000000
# Temperature   551479.0      58.703624     18.685408     -7.290     45.160000
# Fuel_Price    551479.0       3.413010      0.427725      2.472      3.050000
# MarkDown1     551479.0    6530.028000   7871.580020  -2781.450   1346.311000
# MarkDown2     551479.0    2383.036232   7217.211324   -265.760     43.479400
# MarkDown3     551479.0    1115.972744   8373.352083    -29.100      5.590000
# MarkDown4     551479.0    3085.496019   6288.248913      0.220    313.760000
# MarkDown5     551479.0    4547.668542  10583.805672   -185.170   1864.570000
# CPI           551479.0     172.633333     39.772222    126.064    132.698023
# Unemployment  551479.0       7.696895      1.865214      3.684      6.529000
#
#                        50%            75%            max
# Day               16.00000      23.000000      31.000000
# Month              6.00000       9.000000      12.000000
# Year            2011.00000    2012.000000    2013.000000
# Store             22.00000      33.000000      45.000000
# Dept              38.00000      74.000000      99.000000
# Type               1.00000       2.000000       3.000000
# IsHoliday          0.00000       0.000000       1.000000
# Weekly_Sales    7251.15000   19821.990000  693099.360000
# Size          128107.00000  202505.000000  219622.000000
# Temperature       59.94000      73.160000     101.950000
# Fuel_Price         3.52400       3.746000       4.468000
# MarkDown1       4914.57000    8760.455600  103184.980000
# MarkDown2        193.90000    1074.510000  104519.540000
# MarkDown3         24.11000      94.930000  141630.610000
# MarkDown4       1184.40000    3255.698000   67474.850000
# MarkDown5       3312.67000    5533.120000  771448.100000
# CPI              182.54459     214.417648     228.976456
# Unemployment       7.69700       8.523000      14.313000

# %% [markdown]
# Final_Cleaned_datasets

# %%
df
# Out:
#         Day  Month  Year  Store  Dept  Type  IsHoliday  Weekly_Sales    Size  \
# 0         5      2  2010      1     1     1          0    24924.5000  151315
# 1         5      2  2010      1     2     1          0    50605.2700  151315
# 2         5      2  2010      1     3     1          0    13740.1200  151315
# 3         5      2  2010      1     4     1          0    39954.0400  151315
# 4         5      2  2010      1     5     1          0    32229.3800  151315
# ...     ...    ...   ...    ...   ...   ...        ...           ...     ...
# 551474   26      7  2013     45    94     2          0     4113.1254  118221
# 551475   26      7  2013     45    95     2          0    59756.0772  118221
# 551476   26      7  2013     45    96     2          0      237.7128  118221
# 551477   26      7  2013     45    97     2          0     6775.7791  118221
# 551478   26      7  2013     45    98     2          0      711.5973  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 1             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 2             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 3             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# 4             42.31       2.572  8407.5229    3579.21   134.8861   32403.87
# ...             ...         ...        ...        ...        ...        ...
# 551474        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551475        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551476        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551477        76.06       3.804   212.0200     851.73     4.7000      10.88
# 551478        76.06       3.804   212.0200     851.73     4.7000      10.88
#
#         MarkDown5         CPI  Unemployment
# 0        6588.948  211.096358         8.106
# 1        6588.948  211.096358         8.106
# 2        6588.948  211.096358         8.106
# 3        6588.948  211.096358         8.106
# 4        6588.948  211.096358         8.106
# ...           ...         ...           ...
# 551474   1864.570  193.589304         8.684
# 551475   1864.570  193.589304         8.684
# 551476   1864.570  193.589304         8.684
# 551477   1864.570  193.589304         8.684
# 551478   1864.570  193.589304         8.684
#
# [551479 rows x 18 columns]

# %%
df.dtypes
# Out:
# Day               int64
# Month             int64
# Year              int64
# Store             int64
# Dept              int64
# Type              int64
# IsHoliday         int64
# Weekly_Sales    float64
# Size              int64
# Temperature     float64
# Fuel_Price      float64
# MarkDown1       float64
# MarkDown2       float64
# MarkDown3       float64
# MarkDown4       float64
# MarkDown5       float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
df.to_csv('Cleaned_Dataset.csv',index=False)
